# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
# %matplotlib inline

# %%
df = pd.read_csv("manasa_data.csv")

# %%
df.head()
# Out:
#    DOC_ID       LABEL  RATING VERIFIED_PURCHASE PRODUCT_CATEGORY  PRODUCT_ID  \
# 0       1  __label1__       4                 N               PC  B00008NG7N
# 1       2  __label1__       4                 Y         Wireless  B00LH0Y3NM
# 2       3  __label1__       3                 N             Baby  B000I5UZ1Q
# 3       4  __label1__       4                 N  Office Products  B003822IRA
# 4       5  __label1__       4                 N           Beauty  B00PWSAXAM
#
#                                        PRODUCT_TITLE  \
# 0        Targus PAUK10U Ultra Mini USB Keypad, Black
# 1  Note 3 Battery : Stalion Strength Replacement ...
# 2       Fisher-Price Papasan Cradle Swing, Starlight
# 3  Casio MS-80B Standard Function Desktop Calculator
# 4  Shine Whitening - Zero Peroxide Teeth Whitenin...
#
#                REVIEW_TITLE                                        REVIEW_TEXT
# 0                    useful  When least you think so, this product will sav...
# ...

# %%
df.loc[df["LABEL"] == "__label1__", "LABEL"] = '1'
df.loc[df["LABEL"] == "__label2__", "LABEL"] = '0'

# %%
cnt_srs=df.groupby(df["LABEL"]).PRODUCT_CATEGORY.value_counts()
cnt_srs
# Out:
# LABEL  PRODUCT_CATEGORY
# 0      Apparel                   350
#        Automotive                350
#        Baby                      350
#        Beauty                    350
#        Books                     350
#        Camera                    350
#        Electronics               350
#        Furniture                 350
#        Grocery                   350
#        Health & Personal Care    350
#        Home                      350
#        Home Entertainment        350
#        Home Improvement          350
#        Jewelry                   350
#        Kitchen                   350
#        Lawn and Garden           350
#        Luggage                   350
#        Musical Instruments       350
#        Office Products           350
#        Outdoors                  350
#        PC                        350
#        Pet Products              350
#        Shoes                     350
#        Sports                    350
# ...

# %%
plt.figure(figsize=(16,8))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8, color=color[1])
plt.ylabel('Number of Occurrences', fontsize=16)
plt.xlabel('(Label, Product Category)', fontsize=16)
plt.title('Label Vs Product Category', fontsize=18)
plt.xticks(rotation='vertical')
plt.show()

# %%
cnt_srs = df.groupby(df["LABEL"]).RATING.value_counts()
cnt_srs
# Out:
# LABEL  RATING
# 0      5         6151
#        4         1974
#        3          942
#        1          868
#        2          565
# 1      5         6059
#        4         1999
#        3          926
#        1          889
#        2          627
# Name: RATING, dtype: int64

# %%
plt.figure(figsize=(16,8))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8, color=color[1])
plt.ylabel('Number of Occurrences', fontsize=16)
plt.xlabel('(Label, Rating)', fontsize=16)
plt.title('Label Vs Rating', fontsize=18)
plt.xticks(rotation='horizontal')
plt.show()

# %%
cnt_srs = df.groupby(df["RATING"]).PRODUCT_CATEGORY.value_counts()

# %%
plt.figure(figsize=(16,8))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8, color=color[1])
plt.ylabel('Number of Occurrences', fontsize=16)
plt.xlabel('(Rating, Product Category)', fontsize=16)
plt.title('Rating Vs Product_Category', fontsize=18)
plt.xticks(rotation='vertical')
plt.show()

# %%
cnt_srs = df.groupby("VERIFIED_PURCHASE").LABEL.value_counts()
cnt_srs
# Out:
# VERIFIED_PURCHASE  LABEL
# N                  1        7623
#                    0        1679
# Y                  0        8821
#                    1        2877
# Name: LABEL, dtype: int64

# %%
plt.figure(figsize=(16,8))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8, color=color[1])
plt.ylabel('Number of Occurrences', fontsize=16)
plt.xlabel('(Verified Purchase (Y/N), Label)', fontsize=16)
plt.title('Verified_Purchase Vs Labels', fontsize=18)
plt.xticks(rotation='horizontal')
plt.show()

# %%
df1 = df.groupby("LABEL").REVIEW_TEXT

# %%
df['TEXT_LENGTH'] = df['REVIEW_TEXT'].apply(len)

# %%
cnt_srs = df.groupby(["LABEL"]).TEXT_LENGTH.agg(lambda x: sum(x)/len(x))
cnt_srs
# Out:
# LABEL
# 0    428.102857
# 1    316.550000
# Name: TEXT_LENGTH, dtype: float64

# %%
plt.figure(figsize=(16,8))
sns.barplot(cnt_srs.index, cnt_srs.values, alpha=0.8, color=color[0])
plt.ylabel('Text Length', fontsize=16)
plt.xlabel('Label', fontsize=16)
plt.title('Text length Vs Label', fontsize=18)
plt.xticks(rotation='horizontal')
plt.show()

# %%
df['num_sentences'] = df['REVIEW_TEXT'].apply(lambda x: len(str(x).split('.')))

# %%
df
# Out:
#        DOC_ID LABEL  RATING VERIFIED_PURCHASE        PRODUCT_CATEGORY  \
# 0           1     1       4                 N                      PC
# 1           2     1       4                 Y                Wireless
# 2           3     1       3                 N                    Baby
# 3           4     1       4                 N         Office Products
# 4           5     1       4                 N                  Beauty
# 5           6     1       3                 N  Health & Personal Care
# 6           7     1       4                 N                    Toys
# 7           8     1       4                 Y                  Beauty
# 8           9     1       4                 N  Health & Personal Care
# 9          10     1       1                 N  Health & Personal Care
# 10         11     1       1                 N  Health & Personal Care
# 11         12     1       4                 N                 Kitchen
# ...

# %%
# !pip3 install textstat

# %%
import textstat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-34-ca6147c1987b> in <module>
# ----> 1 import textstat
#
# ModuleNotFoundError: No module named 'textstat'
